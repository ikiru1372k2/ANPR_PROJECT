# %%
cd
# Out:
# C:\Users\HP

# %%
import pandas as pd
import xml.etree.ElementTree as xet

# %%
from glob import glob

# %%
path = glob('ML_PROJECT/images/*.xml')
path
# Out:
# ['ML_PROJECT/images\\N1.xml',
#  'ML_PROJECT/images\\N100.xml',
#  'ML_PROJECT/images\\N101.xml',
#  'ML_PROJECT/images\\N102.xml',
#  'ML_PROJECT/images\\N103.xml',
#  'ML_PROJECT/images\\N104.xml',
#  'ML_PROJECT/images\\N105.xml',
#  'ML_PROJECT/images\\N106.xml',
#  'ML_PROJECT/images\\N107.xml',
#  'ML_PROJECT/images\\N108.xml',
#  'ML_PROJECT/images\\N109.xml',
#  'ML_PROJECT/images\\N11.xml',
#  'ML_PROJECT/images\\N110.xml',
#  'ML_PROJECT/images\\N111.xml',
#  'ML_PROJECT/images\\N112.xml',
#  'ML_PROJECT/images\\N113.xml',
#  'ML_PROJECT/images\\N114.xml',
#  'ML_PROJECT/images\\N116.xml',
#  'ML_PROJECT/images\\N117.xml',
#  'ML_PROJECT/images\\N118.xml',
#  'ML_PROJECT/images\\N119.xml',
#  'ML_PROJECT/images\\N12.xml',
#  'ML_PROJECT/images\\N120.xml',
#  'ML_PROJECT/images\\N121.xml',
#  'ML_PROJECT/images\\N122.xml',
#  'ML_PROJECT/images\\N123.xml',
#  'ML_PROJECT/images\\N124.xml',
#  'ML_PROJECT/images\\N126.xml',
#  'ML_PROJECT/images\\N127.xml',
#  'ML_PROJECT/images\\N128.xml',
#  'ML_PROJECT/images\\N129.xml',
#  'ML_PROJECT/images\\N130.xml',
#  'ML_PROJECT/images\\N131.xml',
#  'ML_PROJECT/images\\N132.xml',
#  'ML_PROJECT/images\\N133.xml',
#  'ML_PROJECT/images\\N134.xml',
#  'ML_PROJECT/images\\N135.xml',
#  'ML_PROJECT/images\\N136.xml',
#  'ML_PROJECT/images\\N137.xml',
#  'ML_PROJECT/images\\N138.xml',
#  'ML_PROJECT/images\\N139.xml',
#  'ML_PROJECT/images\\N14.xml',
#  'ML_PROJECT/images\\N140.xml',
#  'ML_PROJECT/images\\N141.xml',
#  'ML_PROJECT/images\\N142.xml',
#  'ML_PROJECT/images\\N143.xml',
#  'ML_PROJECT/images\\N144.xml',
#  'ML_PROJECT/images\\N145.xml',
#  'ML_PROJECT/images\\N147.xml',
#  'ML_PROJECT/images\\N148.xml',
#  'ML_PROJECT/images\\N149.xml',
#  'ML_PROJECT/images\\N15.xml',
#  'ML_PROJECT/images\\N150.xml',
#  'ML_PROJECT/images\\N151.xml',
#  'ML_PROJECT/images\\N152.xml',
#  'ML_PROJECT/images\\N153.xml',
#  'ML_PROJECT/images\\N154.xml',
#  'ML_PROJECT/images\\N155.xml',
#  'ML_PROJECT/images\\N156.xml',
#  'ML_PROJECT/images\\N158.xml',
#  'ML_PROJECT/images\\N16.xml',
#  'ML_PROJECT/images\\N160.xml',
#  'ML_PROJECT/images\\N162.xml',
#  'ML_PROJECT/images\\N163.xml',
#  'ML_PROJECT/images\\N164.xml',
#  'ML_PROJECT/images\\N165.xml',
#  'ML_PROJECT/images\\N166.xml',
#  'ML_PROJECT/images\\N167.xml',
#  'ML_PROJECT/images\\N168.xml',
#  'ML_PROJECT/images\\N169.xml',
#  'ML_PROJECT/images\\N17.xml',
#  'ML_PROJECT/images\\N170.xml',
#  'ML_PROJECT/images\\N171.xml',
#  'ML_PROJECT/images\\N172.xml',
#  'ML_PROJECT/images\\N173.xml',
#  'ML_PROJECT/images\\N174.xml',
#  'ML_PROJECT/images\\N175.xml',
#  'ML_PROJECT/images\\N176.xml',
#  'ML_PROJECT/images\\N177.xml',
#  'ML_PROJECT/images\\N178.xml',
#  'ML_PROJECT/images\\N179.xml',
#  'ML_PROJECT/images\\N18.xml',
#  'ML_PROJECT/images\\N181.xml',
#  'ML_PROJECT/images\\N183.xml',
#  'ML_PROJECT/images\\N184.xml',
#  'ML_PROJECT/images\\N185.xml',
#  'ML_PROJECT/images\\N186.xml',
#  'ML_PROJECT/images\\N187.xml',
#  'ML_PROJECT/images\\N188.xml',
#  'ML_PROJECT/images\\N189.xml',
#  'ML_PROJECT/images\\N19.xml',
#  'ML_PROJECT/images\\N190.xml',
#  'ML_PROJECT/images\\N191.xml',
#  'ML_PROJECT/images\\N192.xml',
#  'ML_PROJECT/images\\N193.xml',
#  'ML_PROJECT/images\\N195.xml',
#  'ML_PROJECT/images\\N196.xml',
#  'ML_PROJECT/images\\N197.xml',
#  'ML_PROJECT/images\\N198.xml',
#  'ML_PROJECT/images\\N199.xml',
#  'ML_PROJECT/images\\N2.xml',
#  'ML_PROJECT/images\\N20.xml',
#  'ML_PROJECT/images\\N200.xml',
#  'ML_PROJECT/images\\N201.xml',
#  'ML_PROJECT/images\\N202.xml',
#  'ML_PROJECT/images\\N203.xml',
#  'ML_PROJECT/images\\N204.xml',
#  'ML_PROJECT/images\\N205.xml',
#  'ML_PROJECT/images\\N206.xml',
#  'ML_PROJECT/images\\N207.xml',
#  'ML_PROJECT/images\\N208.xml',
#  'ML_PROJECT/images\\N209.xml',
#  'ML_PROJECT/images\\N21.xml',
#  'ML_PROJECT/images\\N210.xml',
#  'ML_PROJECT/images\\N211.xml',
#  'ML_PROJECT/images\\N212.xml',
#  'ML_PROJECT/images\\N213.xml',
#  'ML_PROJECT/images\\N214.xml',
#  'ML_PROJECT/images\\N215.xml',
#  'ML_PROJECT/images\\N216.xml',
#  'ML_PROJECT/images\\N217.xml',
#  'ML_PROJECT/images\\N218.xml',
#  'ML_PROJECT/images\\N219.xml',
#  'ML_PROJECT/images\\N22.xml',
#  'ML_PROJECT/images\\N220.xml',
#  'ML_PROJECT/images\\N221.xml',
#  'ML_PROJECT/images\\N222.xml',
#  'ML_PROJECT/images\\N223.xml',
#  'ML_PROJECT/images\\N224.xml',
#  'ML_PROJECT/images\\N225.xml',
#  'ML_PROJECT/images\\N226.xml',
#  'ML_PROJECT/images\\N227.xml',
#  'ML_PROJECT/images\\N229.xml',
#  'ML_PROJECT/images\\N23.xml',
#  'ML_PROJECT/images\\N230.xml',
#  'ML_PROJECT/images\\N231.xml',
#  'ML_PROJECT/images\\N232.xml',
#  'ML_PROJECT/images\\N233.xml',
#  'ML_PROJECT/images\\N234.xml',
#  'ML_PROJECT/images\\N235.xml',
#  'ML_PROJECT/images\\N236.xml',
#  'ML_PROJECT/images\\N237.xml',
#  'ML_PROJECT/images\\N238.xml',
#  'ML_PROJECT/images\\N239.xml',
#  'ML_PROJECT/images\\N24.xml',
#  'ML_PROJECT/images\\N240.xml',
#  'ML_PROJECT/images\\N241.xml',
#  'ML_PROJECT/images\\N242.xml',
#  'ML_PROJECT/images\\N244.xml',
#  'ML_PROJECT/images\\N245.xml',
#  'ML_PROJECT/images\\N246.xml',
#  'ML_PROJECT/images\\N247.xml',
#  'ML_PROJECT/images\\N248.xml',
#  'ML_PROJECT/images\\N25.xml',
#  'ML_PROJECT/images\\N27.xml',
#  'ML_PROJECT/images\\N28.xml',
#  'ML_PROJECT/images\\N3.xml',
#  'ML_PROJECT/images\\N30.xml',
#  'ML_PROJECT/images\\N31.xml',
#  'ML_PROJECT/images\\N32.xml',
#  'ML_PROJECT/images\\N33.xml',
#  'ML_PROJECT/images\\N34.xml',
#  'ML_PROJECT/images\\N35.xml',
#  'ML_PROJECT/images\\N36.xml',
#  'ML_PROJECT/images\\N37.xml',
#  'ML_PROJECT/images\\N38.xml',
#  'ML_PROJECT/images\\N4.xml',
#  'ML_PROJECT/images\\N40.xml',
#  'ML_PROJECT/images\\N42.xml',
#  'ML_PROJECT/images\\N43.xml',
#  'ML_PROJECT/images\\N44.xml',
#  'ML_PROJECT/images\\N45.xml',
#  'ML_PROJECT/images\\N46.xml',
#  'ML_PROJECT/images\\N47.xml',
#  'ML_PROJECT/images\\N48.xml',
#  'ML_PROJECT/images\\N49.xml',
#  'ML_PROJECT/images\\N5.xml',
#  'ML_PROJECT/images\\N50.xml',
#  'ML_PROJECT/images\\N51.xml',
#  'ML_PROJECT/images\\N52.xml',
#  'ML_PROJECT/images\\N53.xml',
#  'ML_PROJECT/images\\N54.xml',
#  'ML_PROJECT/images\\N56.xml',
#  'ML_PROJECT/images\\N57.xml',
#  'ML_PROJECT/images\\N58.xml',
#  'ML_PROJECT/images\\N59.xml',
#  'ML_PROJECT/images\\N6.xml',
#  'ML_PROJECT/images\\N61.xml',
#  'ML_PROJECT/images\\N62.xml',
#  'ML_PROJECT/images\\N63.xml',
#  'ML_PROJECT/images\\N64.xml',
#  'ML_PROJECT/images\\N65.xml',
#  'ML_PROJECT/images\\N66.xml',
#  'ML_PROJECT/images\\N67.xml',
#  'ML_PROJECT/images\\N68.xml',
#  'ML_PROJECT/images\\N69.xml',
#  'ML_PROJECT/images\\N7.xml',
#  'ML_PROJECT/images\\N70.xml',
#  'ML_PROJECT/images\\N72.xml',
#  'ML_PROJECT/images\\N73.xml',
#  'ML_PROJECT/images\\N74.xml',
#  'ML_PROJECT/images\\N75.xml',
#  'ML_PROJECT/images\\N77.xml',
#  'ML_PROJECT/images\\N78.xml',
#  'ML_PROJECT/images\\N79.xml',
#  'ML_PROJECT/images\\N8.xml',
#  'ML_PROJECT/images\\N80.xml',
#  'ML_PROJECT/images\\N81.xml',
#  'ML_PROJECT/images\\N82.xml',
#  'ML_PROJECT/images\\N84.xml',
#  'ML_PROJECT/images\\N85.xml',
#  'ML_PROJECT/images\\N86.xml',
#  'ML_PROJECT/images\\N88.xml',
#  'ML_PROJECT/images\\N89.xml',
#  'ML_PROJECT/images\\N9.xml',
#  'ML_PROJECT/images\\N90.xml',
#  'ML_PROJECT/images\\N91.xml',
#  'ML_PROJECT/images\\N92.xml',
#  'ML_PROJECT/images\\N93.xml',
#  'ML_PROJECT/images\\N94.xml',
#  'ML_PROJECT/images\\N95.xml',
#  'ML_PROJECT/images\\N96.xml',
#  'ML_PROJECT/images\\N97.xml',
#  'ML_PROJECT/images\\N98.xml',
#  'ML_PROJECT/images\\N99.xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:

   
    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#                        filepath  xmin  xmax  ymin  ymax
# 0      ML_PROJECT/images\N1.xml  1093  1396   645   727
# 1    ML_PROJECT/images\N100.xml   134   301   312   350
# 2    ML_PROJECT/images\N101.xml    31   139   128   161
# 3    ML_PROJECT/images\N102.xml   164   316   216   243
# 4    ML_PROJECT/images\N103.xml   813  1067   665   724
# ..                          ...   ...   ...   ...   ...
# 220   ML_PROJECT/images\N95.xml    23   408   173   391
# 221   ML_PROJECT/images\N96.xml   137   352   141   186
# 222   ML_PROJECT/images\N97.xml   175   290   228   255
# 223   ML_PROJECT/images\N98.xml   563   675   207   238
# 224   ML_PROJECT/images\N99.xml   158   389   129   193
#
# [225 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)

# %%
df
# Out:
#                        filepath  xmin  xmax  ymin  ymax
# 0      ML_PROJECT/images\N1.xml  1093  1396   645   727
# 1    ML_PROJECT/images\N100.xml   134   301   312   350
# 2    ML_PROJECT/images\N101.xml    31   139   128   161
# 3    ML_PROJECT/images\N102.xml   164   316   216   243
# 4    ML_PROJECT/images\N103.xml   813  1067   665   724
# ..                          ...   ...   ...   ...   ...
# 220   ML_PROJECT/images\N95.xml    23   408   173   391
# 221   ML_PROJECT/images\N96.xml   137   352   141   186
# 222   ML_PROJECT/images\N97.xml   175   290   228   255
# 223   ML_PROJECT/images\N98.xml   563   675   207   238
# 224   ML_PROJECT/images\N99.xml   158   389   129   193
#
# [225 rows x 5 columns]
